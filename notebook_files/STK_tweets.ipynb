# %%
from dvc.api import make_checkpoint

# %%
# get the tweets using the twitter api
import pandas as pd
import requests
import json

api_key = 'wkxIkajRgLTVkbL2N9zz0G7RN'
api_secret_key = 'nXuL6pk0OaluzSzxIjIbSBhbsz5EfBrsULX6IatiPJ3D00Auk5'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAADx2aQEAAAAAfdKUH18l6uqR9DAwzr4fER9CS1U%3DnHcc0nZYYe8JfMdYMSnlkDiE1Qiupp6zVqRxzUQpoTNn9e78V5'


query = "Short Track Skating"

# Prepare the headers to pass the authentication to Twitter's api
headers = {
    'Authorization': 'Bearer {}'.format(bearer_token),
}

params = (
    ('query', query),
)

# Does the request to get the most recent tweets
response = requests.get('https://api.twitter.com/2/tweets/search/recent', headers=headers, params=params)

# Validates that the query was successful
if response.status_code == 200:
    print("URL of query:", response.url)
    
    # Let's convert the query result to a dictionary that we can iterate over
    tweets =  json.loads(response.text)
    
    for tweet in tweets['data']:
        print("tweet_id: ", tweet['id'], "tweet_text: ", tweet['text'])
# Out:
# URL of query: https://api.twitter.com/2/tweets/search/recent?query=Short+Track+Skating
# tweet_id:  1512384381951827974 tweet_text:  Not long now...⏰
#
# Holly Hoyland and Ethan Treacy are ready to go at the World Short Track Speed Skating Championship.
#
# Here's when they race👇 https://t.co/15cD2X6pdf
# tweet_id:  1512382816104816642 tweet_text:  RT @ISU_Speed: 🔴 The World Championships are getting closer and closer 🤩
#
# Check out the schedules and set your alarm ⏰
#
# Find out where to…
# tweet_id:  1512374445293375489 tweet_text:  🇨🇦 The Maurice Richard Arena in #Montréal is ready for another major competition in ice skating. The best speed skaters compete at the @ISU_Speed World Short Track Speed Skating Championships from April 8-10.
#
# #WorldShortTrack | @SSC_PVC
# tweet_id:  1512368874787852292 tweet_text:  We're disappointed to report that Niall Treacy has had to withdraw from the World Short Track Speed Skating Championships due to a positive COVID-19 test. https://t.co/Z5bPLcjR2a
# tweet_id:  1512357218766635012 tweet_text:  World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Live Stream Available📺📱:  https://t.co/CndWzSNxDz)
# Date : 8-10 April 2022 - Time : Et
# tweet_id:  1512357044833071106 tweet_text:  2022 World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Official Live📺📱:  https://t.co/t6G8hcaAKV)
# Date : 8-10 April 2022 - Time : Et
# tweet_id:  1512310604463177731 tweet_text:  [LIVE] World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Live Now➠ https://t.co/9YAly5HjRw)
# 📅 : 8-10 April 2022 ⏰ Et
# tweet_id:  1512310424506540032 tweet_text:  [LIVE] 2022 World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Live Here📺📱➠ https://t.co/lAFJWK0gPw)
# 📅 : 8-10 April 2022 ⏰ Et
# tweet_id:  1512309264685178883 tweet_text:  ⛸ 2022 #WorldShortTrack Speed Skating Championships in #Canada 🇨🇦 #Montreal start today @ISU_Speed #ShortTrack 📺 Live stream available https://t.co/al9Q1vZ3WJ
# tweet_id:  1512297821881339909 tweet_text:  RT @ISU_Speed: 🔴 The World Championships are getting closer and closer 🤩
#
# Check out the schedules and set your alarm ⏰
#
# Find out where to…

# %%
# convert the tweets information into data frame
stk_tweet = pd.DataFrame({'id':[tweet['id'] for tweet in tweets['data']], 'text':[tweet['text'] for tweet in tweets['data']]})
make_checkpoint()

# %%
stk_tweet
# Out:
#                     id                                               text
# 0  1512384381951827974  Not long now...⏰\n\nHolly Hoyland and Ethan Tr...
# 1  1512382816104816642  RT @ISU_Speed: 🔴 The World Championships are g...
# 2  1512374445293375489  🇨🇦 The Maurice Richard Arena in #Montréal is r...
# 3  1512368874787852292  We're disappointed to report that Niall Treacy...
# 4  1512357218766635012  World Short Track Speed Skating Championships ...
# 5  1512357044833071106  2022 World Short Track Speed Skating Champions...
# 6  1512310604463177731  [LIVE] World Short Track Speed Skating Champio...
# 7  1512310424506540032  [LIVE] 2022 World Short Track Speed Skating Ch...
# 8  1512309264685178883  ⛸ 2022 #WorldShortTrack Speed Skating Champion...
# 9  1512297821881339909  RT @ISU_Speed: 🔴 The World Championships are g...

# %%
# !pip install vaderSentiment
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# Requirement already satisfied: vaderSentiment in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (3.3.2)
# Requirement already satisfied: requests in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from requests->vaderSentiment) (1.26.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from requests->vaderSentiment) (2021.5.30)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# doing the sentiment analysis
analyzer = SentimentIntensityAnalyzer()
list_all_score = []
for t in stk_tweet['text']:
    vs = analyzer.polarity_scores(t)
    print(t)
    print(vs)
    list_all_score.append(vs)
# Out:
# Not long now...⏰
#
# Holly Hoyland and Ethan Treacy are ready to go at the World Short Track Speed Skating Championship.
#
# Here's when they race👇 https://t.co/15cD2X6pdf
# {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.7533}
# RT @ISU_Speed: 🔴 The World Championships are getting closer and closer 🤩
#
# Check out the schedules and set your alarm ⏰
#
# Find out where to…
# {'neg': 0.15, 'neu': 0.75, 'pos': 0.1, 'compound': -0.1531}
# 🇨🇦 The Maurice Richard Arena in #Montréal is ready for another major competition in ice skating. The best speed skaters compete at the @ISU_Speed World Short Track Speed Skating Championships from April 8-10.
#
# #WorldShortTrack | @SSC_PVC
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.872}
# We're disappointed to report that Niall Treacy has had to withdraw from the World Short Track Speed Skating Championships due to a positive COVID-19 test. https://t.co/Z5bPLcjR2a
# {'neg': 0.094, 'neu': 0.699, 'pos': 0.207, 'compound': 0.5719}
# World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Live Stream Available📺📱:  https://t.co/CndWzSNxDz)
# Date : 8-10 April 2022 - Time : Et
# {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.4939}
# 2022 World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Official Live📺📱:  https://t.co/t6G8hcaAKV)
# Date : 8-10 April 2022 - Time : Et
# {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.4939}
# [LIVE] World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Live Now➠ https://t.co/9YAly5HjRw)
# 📅 : 8-10 April 2022 ⏰ Et
# {'neg': 0.094, 'neu': 0.781, 'pos': 0.125, 'compound': 0.2023}
# [LIVE] 2022 World Short Track Speed Skating Championships - Montreal (Canada)
# 🔴Live Here📺📱➠ https://t.co/lAFJWK0gPw)
# 📅 : 8-10 April 2022 ⏰ Et
# {'neg': 0.081, 'neu': 0.811, 'pos': 0.108, 'compound': 0.2023}
# ⛸ 2022 #WorldShortTrack Speed Skating Championships in #Canada 🇨🇦 #Montreal start today @ISU_Speed #ShortTrack 📺 Live stream available https://t.co/al9Q1vZ3WJ
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4939}
# RT @ISU_Speed: 🔴 The World Championships are getting closer and closer 🤩
#
# Check out the schedules and set your alarm ⏰
#
# Find out where to…
# {'neg': 0.15, 'neu': 0.75, 'pos': 0.1, 'compound': -0.1531}

# %%
# merge the sentiment data for each row
stk_tweet = pd.concat([stk_tweet, pd.DataFrame({'neg':[i['neg'] for i in list_all_score],
             'neu':[i['neu'] for i in list_all_score],
             'pos':[i['pos'] for i in list_all_score],
             'compound':[i['compound'] for i in list_all_score]})], axis = 1)
make_checkpoint()

# %%
stk_tweet
# Out:
#                     id                                               text  \
# 0  1512384381951827974  Not long now...⏰\n\nHolly Hoyland and Ethan Tr...
# 1  1512382816104816642  RT @ISU_Speed: 🔴 The World Championships are g...
# 2  1512374445293375489  🇨🇦 The Maurice Richard Arena in #Montréal is r...
# 3  1512368874787852292  We're disappointed to report that Niall Treacy...
# 4  1512357218766635012  World Short Track Speed Skating Championships ...
# 5  1512357044833071106  2022 World Short Track Speed Skating Champions...
# 6  1512310604463177731  [LIVE] World Short Track Speed Skating Champio...
# 7  1512310424506540032  [LIVE] 2022 World Short Track Speed Skating Ch...
# 8  1512309264685178883  ⛸ 2022 #WorldShortTrack Speed Skating Champion...
# 9  1512297821881339909  RT @ISU_Speed: 🔴 The World Championships are g...
#
#      neg    neu    pos  compound
# 0  0.000  0.790  0.210    0.7533
# 1  0.150  0.750  0.100   -0.1531
# 2  0.000  0.769  0.231    0.8720
# 3  0.094  0.699  0.207    0.5719
# 4  0.000  0.887  0.113    0.4939
# 5  0.000  0.887  0.113    0.4939
# 6  0.094  0.781  0.125    0.2023
# 7  0.081  0.811  0.108    0.2023
# 8  0.000  0.856  0.144    0.4939
# 9  0.150  0.750  0.100   -0.1531

# %%
import os

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/project/spark-3.2.1-bin-hadoop3.2"

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("PySpark App") \
    .config("spark.jars", "postgresql-42.3.2.jar") \
    .getOrCreate()

# %%
# convert the data frame into spark data frame
stk_tweet_df = spark.createDataFrame(stk_tweet)

# %%
stk_tweet_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- neg: double (nullable = true)
#  |-- neu: double (nullable = true)
#  |-- pos: double (nullable = true)
#  |-- compound: double (nullable = true)

# %%
# convert the data frame into parquet format
stk_tweet_df.write.parquet("/project/DataEngineering/parquet_files/stk_tweet.parquet", mode = 'overwrite')
make_checkpoint()
